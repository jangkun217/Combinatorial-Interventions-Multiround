# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
num_rounds = 10
num_trials = 20

# %%
#change these to get desired results

method = "optimal"
p = 10
k = 2
n = 100

# %%
with open(f"results/results_multiround_{method}_{p}_{k}_{n}.txt") as file:
    results = json.load(file)

# %%
for i in range(num_rounds):
    np.reshape(results[f'dosage_{i}'],(p,num_trials))

# %%
plt.scatter(range(num_rounds), [np.mean(results[str(i)]) for i in range(num_rounds)])
